# %%
import pandas as pd
from thunderpack import ThunderReader
from openpyxl import load_workbook

# %%
#get list of patients from excel file
#include patient ID and encounter ID in the list
patients = pd.read_excel('/media/cdac-c-15/Thunderpack/Dropbox/cardiac arrest project/cardiac_filtered_orginal .xlsx')
patients = patients[['Unnamed: 0', 'BDSPPatientID', 'SiteID', 'BDSPEncounterID']]
patients.head()
# Out:
#    Unnamed: 0  BDSPPatientID SiteID  BDSPEncounterID
# 0       43477      111189188  S0001        538929570
# 1       88576      111189188  S0001        538929570
# 2      102055      111189188  S0001        538929570
# 3      194219      111189188  S0001        538929570
# 4      132878      111189188  S0001        538929570

# %%
uniqueIDs = patients['BDSPPatientID']
uniqueIDs = uniqueIDs.drop_duplicates()
print(uniqueIDs)
# Out:
# 0        111189188
# 12       111200203
# 13       111204957
# 18       111205248
# 19       111222562
#            ...
# 12131    122423260
# 12133    122449422
# 12136    122474334
# 12139    122479673
# 12141    122519256
# Name: BDSPPatientID, Length: 1650, dtype: int64

# %%
# read into demographics file to make a dataframe that contains information about all patients
reader = ThunderReader('/media/cdac-c-15/Thunderpack/Dropbox/zz_EHR_Thunderpacks/MGB/thunderpack_demographics_MGB')
dfs = []
for i in range(1, (len(list(reader.keys())))):
    df = reader[f'demographics_partition_{i}']
    df = df[df['BDSPPatientID'].isin(uniqueIDs)]
    dfs.append(df)
    del df
demographics = pd.concat(dfs, axis=0, ignore_index=True)     #puts data into rows and columns

del dfs     # clean up my data a little bit
del reader

demographics = demographics.drop_duplicates(subset='BDSPPatientID')
print(len(demographics))      #print the number of notes found with those ICD codes
demographics.head()      #print the first few lines of the filtered list of notes
# Out:
# 1650
#    BDSPPatientID DateOfBirth DateOfDeath DateOfDeathMARegistryData  \
# 0      117039206  1967-10-05  2021-11-20                2021-11-20
# 1      119106063  1963-06-28        None                      None
# 2      114917293  1950-04-12  2019-07-28                2019-07-28
# 3      114886961  2000-03-12        None                      None
# 4      116442969  2001-05-19  2021-03-01                2021-03-01
#
#                  PatientRace EthnicGroupDSC     MaritalStatusDSC  \
# 0                      White   Not Hispanic               Single
# 1  Black or African American    Unavailable         Life Partner
# 2  Black or African American   Not Hispanic  Married/Civil Union
# 3                      Other       Hispanic               Single
# 4                      Other       Hispanic               Single
#
#       ReligionDSC LanguageDSC                         VeteranStatusDSC  ...  \
# 0         Atheist     English  No, Never Served or Is Currently Active  ...
# 1  Not Affiliated     English  No, Never Served or Is Currently Active  ...
# 2  Roman Catholic     English  No, Never Served or Is Currently Active  ...
# 3  Not Affiliated     Spanish  No, Never Served or Is Currently Active  ...
# 4  Roman Catholic     Spanish  No, Never Served or Is Currently Active  ...
#
#   PrimaryCauseOfDeathDSC UNOSPrimaryCauseOfDeathTXT  \
# 0                   None                       None
# 1                   None                       None
# 2                   None                       None
# 3                   None                       None
# 4                   None                       None
#
#   FirstContributoryCauseOfDeathDSC UNOSContributoryCauseOfDeath01TXT  \
# 0                             None                              None
# 1                             None                              None
# 2                             None                              None
# 3                             None                              None
# 4                             None                              None
#
#   SecondContributoryCauseOfDeathDSC UNOSContributoryCauseOfDeath02TXT  \
# 0                              None                               NaN
# 1                              None                               NaN
# 2                              None                               NaN
# 3                              None                               NaN
# 4                              None                               NaN
#
#          EducationLevelDSC GenderIdentityDSC SexAssignedAtBirthDSC  \
# 0      Graduated - College              None                  None
# 1                    Other              None                  None
# 2  Graduated - High School              None                  None
# 3  Graduated - High School              Male                  Male
# 4  Graduated - High School              None                  None
#
#            BDSPLastModifiedDTS
# 0  2022-11-29 10:00:51.2500000
# 1  2022-07-17 17:57:14.1830000
# 2  2022-11-29 13:01:12.0500000
# 3  2022-07-17 17:57:14.1830000
# 4  2022-11-29 14:03:15.2366667
#
# [5 rows x 21 columns]

# %%
# merge the dfs to make final df contain missing data
mergedInformation = patients.merge(demographics[['BDSPPatientID', 'PatientRace', 'EthnicGroupDSC']], on='BDSPPatientID', how='left')
mergedInformation.head()
# Out:
#    Unnamed: 0  BDSPPatientID SiteID  BDSPEncounterID  \
# 0       43477      111189188  S0001        538929570
# 1       88576      111189188  S0001        538929570
# 2      102055      111189188  S0001        538929570
# 3      194219      111189188  S0001        538929570
# 4      132878      111189188  S0001        538929570
#
#                  PatientRace EthnicGroupDSC
# 0  Black or African American   Not Hispanic
# 1  Black or African American   Not Hispanic
# 2  Black or African American   Not Hispanic
# 3  Black or African American   Not Hispanic
# 4  Black or African American   Not Hispanic

# %%
excel_df = pd.read_excel('/media/cdac-c-15/Thunderpack/Dropbox/cardiac arrest project/cardiac_filtered_orginal .xlsx', sheet_name='cardiac_filtered_new')

# %%
# check if the dfs are able to be overlaid
print(len(excel_df))
print(len(mergedInformation))
print(len(patients))
# Out:
# 12146
# 12146
# 12146

# %%
#merge excel sheet with existing data
# Assuming 'PatientID' and 'EncounterID' are columns in both DataFrames
# and we want to update the 'Data_Column' in the Excel DataFrame
merged_df = excel_df.merge(mergedInformation[['Unnamed: 0', 'BDSPPatientID', 'BDSPEncounterID', 'PatientRace', 'EthnicGroupDSC']], on=['Unnamed: 0', 'BDSPPatientID', 'BDSPEncounterID'], how='left')

print(len(merged_df))
merged_df.head()
# Out:
# 12146
#    Unnamed: 0  group  BDSPPatientID SiteID BonoboIndex sparcnetID  \
# 0       43477      9      111189188  S0001         NaN    pat0005
# 1       88576      9      111189188  S0001         NaN    pat0005
# 2      102055      9      111189188  S0001         NaN    pat0005
# 3      194219      9      111189188  S0001         NaN    pat0005
# 4      132878      9      111189188  S0001         NaN    pat0005
#
#                                       HashFolderName  \
# 0  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...
# 1  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...
# 2  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...
# 3  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...
# 4  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...
#
#                                         HashFileName          BidsFolder  \
# 0  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...  sub-S0001111189188
# 1  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...  sub-S0001111189188
# 2  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...  sub-S0001111189188
# 3  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...  sub-S0001111189188
# 4  a81e3504efe7bde263ce334822e05527ed3c6aaa2dc779...  sub-S0001111189188
#
#    SessionID_new  ... jae jeavons sunflower dravet eses cjd angelman  \
# 0              7  ...   0       0         0      0    0   0        0
# 1              7  ...   0       0         0      0    0   0        0
# 2              6  ...   0       0         0      0    0   0        0
# 3              6  ...   0       0         0      0    0   0        0
# 4              5  ...   0       0         0      0    0   0        0
#
#   jeavonssunflower                PatientRace EthnicGroupDSC
# 0              NaN  Black or African American   Not Hispanic
# 1              NaN  Black or African American   Not Hispanic
# 2              NaN  Black or African American   Not Hispanic
# 3              NaN  Black or African American   Not Hispanic
# 4              NaN  Black or African American   Not Hispanic
#
# [5 rows x 88 columns]

# %%
# get the information that I need from the merged df

# Select the 'race' and 'ethnicity' rows from the DataFrame
selected_rows = merged_df[['PatientRace', 'EthnicGroupDSC']]

# Convert the selected rows into lists
race_data = selected_rows['PatientRace'].tolist()
ethnicity_data = selected_rows['EthnicGroupDSC'].tolist()

# %%
# Load the workbook and the specific sheet
path = '/media/cdac-c-15/Thunderpack/Dropbox/cardiac arrest project/cardiac_filtered_orginal .xlsx'
sheet_name='cardiac_filtered_new'
workbook = load_workbook(path)
sheet = workbook[sheet_name]
# 23 is race
# 24 is ethnicity
# starting row is 2

starting_row = 2

# Add new columns to the sheet
for row_num, (value1, value2) in enumerate(zip(race_data, ethnicity_data), start=starting_row):
    sheet.cell(row=row_num, column=22, value=value1)
    sheet.cell(row=row_num, column=23, value=value2)

workbook.save(path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[22], line 17
#      14     sheet.cell(row=row_num, column=22, value=value1)
#      15     sheet.cell(row=row_num, column=23, value=value2)
# ---> 17 workbook.save(path)
#
# File ~/miniconda3/envs/nax/lib/python3.11/site-packages/openpyxl/workbook/workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File ~/miniconda3/envs/nax/lib/python3.11/site-packages/openpyxl/writer/excel.py:291, in save_workbook(workbook, filename)
#     279 def save_workbook(workbook, filename):
#     280     """Save the given workbook on the filesystem under the name filename.
#     281
#     282     :param workbook: the workbook to save
#    (...)
#     289
#     290     """
# --> 291     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292     workbook.properties.modified = datetime.datetime.utcnow()
#     293     writer = ExcelWriter(workbook, archive)
#
# File ~/miniconda3/envs/nax/lib/python3.11/zipfile.py:1294, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1292 while True:
#    1293     try:
# -> 1294         self.fp = io.open(file, filemode)
#    1295     except OSError:
#    1296         if filemode in modeDict:
#
# OSError: [Errno 30] Read-only file system: '/media/cdac-c-15/Thunderpack/Dropbox/cardiac arrest project/cardiac_filtered_orginal .xlsx'
